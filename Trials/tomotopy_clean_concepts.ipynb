# %%
import os
import re
import json
import pandas as pd
import tomotopy as tp
from tqdm import tqdm
import nltk
from nltk.stem import WordNetLemmatizer, PorterStemmer
from nltk.corpus import stopwords, wordnet

# %%
# Load Data
df_patents = pd.read_csv('/Users/juergenthiesen/Documents/Patentsview/Cleantech CSV Files/g_patent_Y02.csv')
df_cpc = pd.read_csv('/Users/juergenthiesen/Documents/Patentsview/Cleantech CSV Files/g_cpc_current_Y02.csv')

# Drop all classes unequal to Y02 from df_cpc
df_cpc = df_cpc[df_cpc['cpc_class'].str.contains('Y02')]

# Merge data on patent_id, keep duplicates
df = pd.merge(df_patents, df_cpc, on='patent_id', how='left')

# Drop all data in df with title or abstract NaN
df = df.dropna(subset=['patent_title', 'patent_abstract'])

# Merge title and abstract with [SEP] token
# df['patent_title_abstract'] = df['patent_title'] + ' [SEP] ' + df['patent_abstract']

# Merge title and abstract
df['patent_title_abstract'] = df['patent_title'] + ' ' + df['patent_abstract']

# Drop duplicates of patent_id + cpc_subclass
df = df.drop_duplicates(subset=['patent_id', 'cpc_subclass'])

# Determine the minimum count of patents per cpc_subclass
min_count = df['cpc_subclass'].value_counts().min()

# Randomly sample the rounded down count of patents per cpc_subclass
df = df.groupby('cpc_subclass').apply(lambda x: x.sample(min_count, random_state=42))

# Merge rows with same patent_id and keep all cpc_subclasses
df = df.groupby('patent_id').agg({'patent_title_abstract': 'first', 'cpc_subclass': lambda x: list(x)})

# Set label column to 0 for Y02A, 1 for Y02B, 2 for Y02C, 3 for Y02D, 4 for Y02E, 5 for Y02P, 6 for Y02T, 7 for Y02W
# df['label'] = df['cpc_subclass'].map({'Y02A': 0, 'Y02B': 1, 'Y02C': 2, 'Y02D': 3, 'Y02E': 4, 'Y02P': 5, 'Y02T': 6, 'Y02W': 7})

# %%
# Split data into train and test set
df_train = df.sample(frac=0.8, random_state=42)
df_test = df.drop(df_train.index)

# Function to obtain part-of-speech tags for each word in corpus (only valid options for lemmatizer)
def get_wordnet_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

lemmatizer = WordNetLemmatizer()
# stemmer = PorterStemmer()

# Initialize model
PLDA_model_IDF = tp.PLDAModel(tw=tp.TermWeight.IDF, topics_per_label=10, seed=42, latent_topics=1)
PLDA_model_ONE = tp.PLDAModel(tw=tp.TermWeight.ONE, topics_per_label=10, seed=42, latent_topics=1)
PLDA_model_PMI = tp.PLDAModel(tw=tp.TermWeight.PMI, topics_per_label=10, seed=42, latent_topics=1)

# Add documents to model
for index, row in tqdm(df_train.iterrows()):
    # Lowercase all words
    clean_document = row['claim_fulltext'].lower()

    ### Regex ###
    # Replace '-' and '/' with spaces
    clean_document = re.sub(r'[-/]', ' ', clean_document)
    # Remove puncutation
    clean_document = re.sub(r'[^\w\s]', '', clean_document)
    # Remove numbers
    clean_document = re.sub(r'\d+', '', clean_document)
    # # Remove words with less than 2 characters
    # clean_document = re.sub(r'\b\w{1,3}\b', '', clean_document)
    # Remove extra spaces
    clean_document = re.sub(r'\s+', ' ', clean_document)
    # Remove non-alphabetic characters
    clean_document = re.sub(r'[^a-zA-Z]', ' ', clean_document)
    # Remove stopwords
    clean_document = [token for token in clean_document.split() if token not in stopwords.words('english')]
    # Lemmatize words
    pos_tagged_tokens = nltk.pos_tag(clean_document)
    clean_document = [lemmatizer.lemmatize(token, get_wordnet_pos(tag)) for token, tag in pos_tagged_tokens]
    # Stem words
    # clean_document = [stemmer.stem(token) for token in clean_document]
    # Set labels
    label = row['cpc_subclass']
    # Add document and labels to model
    PLDA_model_IDF.add_doc(clean_document, labels=label)
    PLDA_model_ONE.add_doc(clean_document, labels=label)
    PLDA_model_PMI.add_doc(clean_document, labels=label)
# Out:
# 40617it [05:14, 129.19it/s]

# %%
# Instantiate labelled LDA model (source: https://bab2min.github.io/tomotopy/v/en/#tomotopy.PLDAModel)
# Term weight options: IDF, ONE (equally weighted), PMI (Pointwise Mutual Information)

# Train a topic model using tomotopy library
PLDA_model_IDF.burn_in = 5
print('Start training model:')
for i in range(0, 100, 10):
    PLDA_model_IDF.train(iter=10, workers=0)
    # print('Iteration: {}\tLog-likelihood: {}'.format(i, PLDA_model.ll_per_word))

PLDA_model_IDF.summary()

# Save model
PLDA_model_IDF.save('/Users/juergenthiesen/Documents/Patentsview/Cleantech Concepts/PLDA_IDF_model_cleantech_concepts.bin')
# Out:
# Start training model:
# <Basic Info>
# | PLDAModel (current version: 0.12.5)
# | 40617 docs, 2967403 words
# | Total Vocabs: 36754, Used Vocabs: 36754
# | Entropy of words: 7.47317
# | Entropy of term-weighted words: 8.31698
# | Removed Vocabs: <NA>
# | Label of docs and its distribution
# |  Y02A: 5120
# |  Y02B: 5157
# |  Y02P: 5156
# |  Y02E: 5147
# |  Y02D: 5195
# |  Y02W: 5073
# |  Y02C: 5172
# |  Y02T: 5159
# |
# <Training Info>
# | Iterations: 100, Burn-in steps: 5
# | Optimization Interval: 10
# | Log-likelihood per word: -7.49045
# |
# <Initial Parameters>
# | tw: TermWeight.PMI
# | min_cf: 0 (minimum collection frequency of words)
# | min_df: 0 (minimum document frequency of words)
# | rm_top: 0 (the number of top words to be removed)
# | latent_topics: 1 (the number of latent topics, which are shared to all documents, between 1 ~ 32767)
# | topics_per_label: 10 (the number of topics per label between 1 ~ 32767)
# | alpha: [0.1] (hyperparameter of Dirichlet distribution for document-topic, given as a single `float` in case of symmetric prior and as a list with length `k` of `float` in case of asymmetric prior.)
# | eta: 0.01 (hyperparameter of Dirichlet distribution for topic-word)
# | seed: 42 (random seed)
# | trained in version 0.12.5
# |
# <Parameters>
# | alpha (Dirichlet prior on the per-document topic distributions)
# |  [0.00425679 0.00443916 0.00514071 0.00375833 0.00431294 0.00232539
# |   0.0044336  0.00787122 0.00517525 0.00776497 0.00438985 0.00525913
# |   0.00317487 0.00433701 0.00261453 0.00435429 0.00369459 0.00270422
# |   0.00452412 0.00460332 0.00479551 0.0047435  0.00420825 0.00373141
# |   0.00317315 0.00348422 0.00690535 0.0047901  0.00371579 0.00439258
# |   0.00317565 0.00334653 0.00338891 0.00383837 0.00450444 0.00518314
# |   0.00290793 0.00479403 0.00443778 0.00471357 0.00546709 0.00506747
# |   0.00440005 0.00495797 0.00455164 0.0054213  0.00513992 0.00536201
# |   0.00467844 0.0044311  0.00518682 0.00419857 0.00518667 0.00454504
# |   0.00368929 0.00409009 0.00448513 0.00455101 0.00339346 0.00528141
# |   0.00460137 0.00403374 0.00651898 0.00451499 0.00519176 0.00347591
# |   0.00416417 0.00479527 0.00426364 0.00481174 0.00429845 0.00601307
# |   0.0074912  0.00243957 0.00385476 0.00541356 0.00345799 0.0041709
# |   0.0052705  0.00506862 0.20642643]
# | eta (Dirichlet prior on the per-topic word distribution)
# |  0.01
# |
# <Topics>
# | Label Y02A-0 (#0) (28019) : virus antibody infection vaccine composition
# | Label Y02A-1 (#1) (19034) : exhaust catalyst gas nox nitrogen
# | Label Y02A-2 (#2) (25655) : plant composition invention protein polypeptide
# | Label Y02A-3 (#3) (9821) : analyte sensor solution calibration data
# | Label Y02A-4 (#4) (12819) : composition blood inhibitor disease agent
# | Label Y02A-5 (#5) (9771) : weather radar data fish information
# | Label Y02A-6 (#6) (16588) : compound r composition formula inhibitor
# | Label Y02A-7 (#7) (15453) : plant protein gene sequence nucleic
# | Label Y02A-8 (#8) (10994) : oil patient fish composition corn
# | Label Y02A-9 (#9) (10257) : patient sample disease subject test
# | Label Y02B-0 (#10) (26836) : light emit illumination device control
# | Label Y02B-1 (#11) (55961) : switch voltage power converter dc
# | Label Y02B-2 (#12) (23524) : solar panel module roof photovoltaic
# | Label Y02B-3 (#13) (24976) : circuit switch voltage terminal connect
# | Label Y02B-4 (#14) (13779) : lamp lead light ballast compartment
# | Label Y02B-5 (#15) (38124) : power voltage circuit current signal
# | Label Y02B-6 (#16) (26881) : heat air refrigerant exchanger temperature
# | Label Y02B-7 (#17) (16148) : light lead emit lamp diode
# | Label Y02B-8 (#18) (31480) : power device meter control energy
# | Label Y02B-9 (#19) (29008) : circuit switch voltage lamp current
# | Label Y02P-0 (#20) (38024) : electrode solder first battery substrate
# | Label Y02P-1 (#21) (30357) : catalyst reaction reactor process hydrocarbon
# | Label Y02P-2 (#22) (18961) : copper solution metal acid leach
# | Label Y02P-3 (#23) (15037) : metal solution process solid ore
# | Label Y02P-4 (#24) (19559) : group compound formula rsup r
# | Label Y02P-5 (#25) (16508) : electrode battery positive negative lithium
# | Label Y02P-6 (#26) (16915) : layer substrate first surface wire
# | Label Y02P-7 (#27) (29853) : layer electrode cell material substrate
# | Label Y02P-8 (#28) (12690) : silicon blade metal glass wind
# | Label Y02P-9 (#29) (18144) : metal polymer iron catalyst melt
# | Label Y02E-0 (#30) (18917) : battery charge cell storage state
# | Label Y02E-1 (#31) (18294) : group material produce r lithium
# | Label Y02E-2 (#32) (18603) : wind turbine rotor blade rod
# | Label Y02E-3 (#33) (31125) : layer substrate display film electrode
# | Label Y02E-4 (#34) (19076) : fuel cell anode stack electrolyte
# | Label Y02E-5 (#35) (15502) : layer substrate film region electrode
# | Label Y02E-6 (#36) (16865) : battery cell first module case
# | Label Y02E-7 (#37) (34677) : electrode lithium material electrolyte battery
# | Label Y02E-8 (#38) (26521) : power voltage dc conversion output
# | Label Y02E-9 (#39) (26666) : battery plate portion member assembly
# | Label Y02D-0 (#40) (42066) : power unit information device apparatus
# | Label Y02D-1 (#41) (39477) : memory device data processor interface
# | Label Y02D-2 (#42) (29487) : data network packet link ue
# | Label Y02D-3 (#43) (30189) : resource information data ue signal
# | Label Y02D-4 (#44) (22024) : signal page code receiver radio
# | Label Y02D-5 (#45) (43239) : network wireless node communication device
# | Label Y02D-6 (#46) (35384) : communication device network wireless power
# | Label Y02D-7 (#47) (42996) : power processor core state device
# | Label Y02D-8 (#48) (32854) : communication station wireless radio signal
# | Label Y02D-9 (#49) (41227) : memory clock data cache signal
# | Label Y02W-0 (#50) (27679) : material resin polyester weight polymer
# | Label Y02W-1 (#51) (18426) : waste water material filter wastewater
# | Label Y02W-2 (#52) (16637) : container bag reusable plastic carpet
# | Label Y02W-3 (#53) (24311) : cement wastewater sludge treatment composition
# | Label Y02W-4 (#54) (23173) : waste calcium material water composition
# | Label Y02W-5 (#55) (30177) : container wall end tire member
# | Label Y02W-6 (#56) (16867) : rubber waste material metal particle
# | Label Y02W-7 (#57) (35168) : waste water sludge treatment wastewater
# | Label Y02W-8 (#58) (14696) : cement fiber composition cementitious material
# | Label Y02W-9 (#59) (19540) : plastic material paper pulp fiber
# | Label Y02C-0 (#60) (45161) : gas stream dioxide carbon co
# | Label Y02C-1 (#61) (17214) : membrane metal co organic compound
# | Label Y02C-2 (#62) (14796) : formation hydrocarbon may carbon situ
# | Label Y02C-3 (#63) (32381) : gas exhaust co stream carbon
# | Label Y02C-4 (#64) (30474) : membrane gas separation adsorption pressure
# | Label Y02C-5 (#65) (27852) : carbon dioxide gas co capture
# | Label Y02C-6 (#66) (30665) : gas co solution absorption absorbent
# | Label Y02C-7 (#67) (25364) : gas exhaust nox carbon dioxide
# | Label Y02C-8 (#68) (25638) : adsorption adsorbent swing bed gas
# | Label Y02C-9 (#69) (29174) : metal catalyst sorbent adsorbent zeolite
# | Label Y02T-0 (#70) (21855) : wing blade airfoil aircraft edge
# | Label Y02T-1 (#71) (31409) : exhaust engine fuel gas combustion
# | Label Y02T-2 (#72) (18036) : first vehicle side cool face
# | Label Y02T-3 (#73) (13146) : ring vane guide rubber flange
# | Label Y02T-4 (#74) (42188) : motor vehicle drive electric torque
# | Label Y02T-5 (#75) (49295) : vehicle charge battery power electric
# | Label Y02T-6 (#76) (14673) : catalyst electrode battery lithium oxide
# | Label Y02T-7 (#77) (20448) : wheel shaft portion rotor turbine
# | Label Y02T-8 (#78) (27344) : engine air combustion intake valve
# | Label Y02T-9 (#79) (42845) : engine combustion fuel valve injection
# | Latent 0 (#80) (934406) : heat system water air flow
# |
# /var/folders/0j/wnvgdqzd6ylfts3hrw81r15r0000gn/T/ipykernel_19261/4255251590.py:8: RuntimeWarning: The training result may differ even with fixed seed if `workers` != 1.
#   PLDA_model_PMI.train(iter=10, workers=0)
