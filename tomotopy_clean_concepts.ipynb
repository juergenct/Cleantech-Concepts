# %%
import os
import re
import json
import pandas as pd
import tomotopy as tp
from tqdm import tqdm
import nltk
from nltk.stem import WordNetLemmatizer, PorterStemmer
from nltk.corpus import stopwords, wordnet

# %%
# Load Data
df_patents = pd.read_csv('/Users/juergenthiesen/Documents/Patentsview/Cleantech CSV Files/g_patent_Y02.csv')
df_cpc = pd.read_csv('/Users/juergenthiesen/Documents/Patentsview/Cleantech CSV Files/g_cpc_current_Y02.csv')

# Drop all classes unequal to Y02 from df_cpc
df_cpc = df_cpc[df_cpc['cpc_class'].str.contains('Y02')]

# Merge data on patent_id, keep duplicates
df = pd.merge(df_patents, df_cpc, on='patent_id', how='left')

# Drop all data in df with title or abstract NaN
df = df.dropna(subset=['patent_title', 'patent_abstract'])

# Merge title and abstract with [SEP] token
# df['patent_title_abstract'] = df['patent_title'] + ' [SEP] ' + df['patent_abstract']

# Merge title and abstract
df['patent_title_abstract'] = df['patent_title'] + ' ' + df['patent_abstract']

# Drop duplicates of patent_id + cpc_subclass
df = df.drop_duplicates(subset=['patent_id', 'cpc_subclass'])

# Determine the minimum count of patents per cpc_subclass
min_count = df['cpc_subclass'].value_counts().min()

# Randomly sample the rounded down count of patents per cpc_subclass
df = df.groupby('cpc_subclass').apply(lambda x: x.sample(min_count, random_state=42))

# Merge rows with same patent_id and keep all cpc_subclasses
df = df.groupby('patent_id').agg({'patent_title_abstract': 'first', 'cpc_subclass': lambda x: list(x)})

# Set label column to 0 for Y02A, 1 for Y02B, 2 for Y02C, 3 for Y02D, 4 for Y02E, 5 for Y02P, 6 for Y02T, 7 for Y02W
# df['label'] = df['cpc_subclass'].map({'Y02A': 0, 'Y02B': 1, 'Y02C': 2, 'Y02D': 3, 'Y02E': 4, 'Y02P': 5, 'Y02T': 6, 'Y02W': 7})

# %%
# Split data into train and test set
df_train = df.sample(frac=0.8, random_state=42)
df_test = df.drop(df_train.index)

# Function to obtain part-of-speech tags for each word in corpus (only valid options for lemmatizer)
def get_wordnet_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

lemmatizer = WordNetLemmatizer()
# stemmer = PorterStemmer()

# Initialize model
PLDA_model_IDF = tp.PLDAModel(tw=tp.TermWeight.IDF, topics_per_label=10, seed=42)

# Add documents to model
for index, row in tqdm(df_train.iterrows()):
    # Lowercase all words
    clean_document = row['patent_title_abstract'].lower()

    ### Regex ###
    # Replace '-' and '/' with spaces
    clean_document = re.sub(r'[-/]', ' ', clean_document)
    # Remove puncutation
    clean_document = re.sub(r'[^\w\s]', '', clean_document)
    # Remove numbers
    clean_document = re.sub(r'\d+', '', clean_document)
    # # Remove words with less than 2 characters
    # clean_document = re.sub(r'\b\w{1,3}\b', '', clean_document)
    # Remove extra spaces
    clean_document = re.sub(r'\s+', ' ', clean_document)
    # Remove non-alphabetic characters
    clean_document = re.sub(r'[^a-zA-Z]', ' ', clean_document)
    # Remove stopwords
    clean_document = [token for token in clean_document.split() if token not in stopwords.words('english')]
    # Lemmatize words
    pos_tagged_tokens = nltk.pos_tag(clean_document)
    clean_document = [lemmatizer.lemmatize(token, get_wordnet_pos(tag)) for token, tag in pos_tagged_tokens]
    # Stem words
    # clean_document = [stemmer.stem(token) for token in clean_document]
    # Set labels
    label = row['cpc_subclass']
    # Add document and labels to model
    PLDA_model_IDF.add_doc(clean_document, labels=label)
# Out:
# 40617it [05:15, 128.93it/s]

# %%
# Instantiate labelled LDA model (source: https://bab2min.github.io/tomotopy/v/en/#tomotopy.PLDAModel)
# Term weight options: IDF, ONE (equally weighted), PMI (Pointwise Mutual Information)

# Train a topic model using tomotopy library
PLDA_model_IDF.burn_in = 5
print('Start training model:')
for i in range(0, 100, 10):
    PLDA_model_IDF.train(10)
    # print('Iteration: {}\tLog-likelihood: {}'.format(i, PLDA_model.ll_per_word))

PLDA_model_IDF.summary()

# Save model
PLDA_model_IDF.save('/Users/juergenthiesen/Documents/Patentsview/Cleantech Concepts/PLDA_IDF_model_cleantech_concepts.bin')
# Out:
# Start training model:
# <Basic Info>
# | PLDAModel (current version: 0.12.5)
# | 40617 docs, 2967403 words
# | Total Vocabs: 36754, Used Vocabs: 36754
# | Entropy of words: 7.47317
# | Entropy of term-weighted words: 8.35301
# | Removed Vocabs: <NA>
# | Label of docs and its distribution
# |  Y02A: 5120
# |  Y02B: 5157
# |  Y02P: 5156
# |  Y02E: 5147
# |  Y02D: 5195
# |  Y02W: 5073
# |  Y02C: 5172
# |  Y02T: 5159
# |
# <Training Info>
# | Iterations: 100, Burn-in steps: 5
# | Optimization Interval: 10
# | Log-likelihood per word: -7.52633
# |
# <Initial Parameters>
# | tw: TermWeight.IDF
# | min_cf: 0 (minimum collection frequency of words)
# | min_df: 0 (minimum document frequency of words)
# | rm_top: 0 (the number of top words to be removed)
# | latent_topics: 0 (the number of latent topics, which are shared to all documents, between 1 ~ 32767)
# | topics_per_label: 10 (the number of topics per label between 1 ~ 32767)
# | alpha: [0.1] (hyperparameter of Dirichlet distribution for document-topic, given as a single `float` in case of symmetric prior and as a list with length `k` of `float` in case of asymmetric prior.)
# | eta: 0.01 (hyperparameter of Dirichlet distribution for topic-word)
# | seed: 42 (random seed)
# | trained in version 0.12.5
# |
# <Parameters>
# | alpha (Dirichlet prior on the per-document topic distributions)
# |  [0.00442221 0.00584469 0.00554871 0.00588035 0.0044275  0.00541178
# |   0.00511995 0.00549811 0.00434473 0.0048844  0.00511599 0.00641923
# |   0.00467886 0.00491985 0.00562071 0.00442574 0.00542453 0.00459089
# |   0.00582639 0.00404543 0.00561342 0.00445166 0.00505302 0.00290406
# |   0.00527538 0.00570532 0.00562107 0.00541715 0.0044587  0.00497317
# |   0.00407972 0.00461902 0.00539758 0.00517188 0.00498552 0.00575854
# |   0.00498996 0.00581976 0.00596745 0.00342995 0.00583725 0.00490061
# |   0.00462498 0.00454687 0.0053001  0.00485172 0.00535296 0.00534542
# |   0.00424068 0.00484704 0.00551342 0.00535745 0.00541319 0.00532677
# |   0.00486875 0.00541295 0.00534085 0.00561267 0.00406903 0.00417784
# |   0.00533557 0.00551589 0.00485421 0.00456448 0.00530457 0.00499412
# |   0.00530368 0.00542007 0.0052717  0.00383608 0.00482789 0.00529776
# |   0.0051573  0.00559756 0.00538085 0.00485634 0.00424248 0.00442732
# |   0.00532321 0.00457815]
# | eta (Dirichlet prior on the per-topic word distribution)
# |  0.01
# |
# <Topics>
# | Label Y02A-0 (#0) (30789) : antibody virus composition vaccine antigen
# | Label Y02A-1 (#1) (16074) : wind manure waste fish radar
# | Label Y02A-2 (#2) (31625) : composition compound disease infection pharmaceutical
# | Label Y02A-3 (#3) (53257) : exhaust water air heat gas
# | Label Y02A-4 (#4) (21219) : patient data sample model blood
# | Label Y02A-5 (#5) (30205) : water radar irrigation weather filter
# | Label Y02A-6 (#6) (33880) : plant protein gene sequence polypeptide
# | Label Y02A-7 (#7) (49432) : wall surface member water body
# | Label Y02A-8 (#8) (28314) : oil water composition salt material
# | Label Y02A-9 (#9) (31960) : sensor catalyst nox analyte exhaust
# | Label Y02B-0 (#10) (30248) : light power device control sensor
# | Label Y02B-1 (#11) (98286) : voltage switch circuit power converter
# | Label Y02B-2 (#12) (21690) : light emit lamp phosphor lead
# | Label Y02B-3 (#13) (45997) : solar lamp panel module roof
# | Label Y02B-4 (#14) (50608) : power control device load data
# | Label Y02B-5 (#15) (15662) : solar layer roof ultrasonic building
# | Label Y02B-6 (#16) (45718) : heat air exchanger refrigerant temperature
# | Label Y02B-7 (#17) (45171) : circuit current switch voltage power
# | Label Y02B-8 (#18) (23859) : heat compressor water evaporator cool
# | Label Y02B-9 (#19) (30634) : light control sensor device source
# | Label Y02P-0 (#20) (55603) : data control machine tool system
# | Label Y02P-1 (#21) (38743) : catalyst reaction process hydrocarbon hydrogen
# | Label Y02P-2 (#22) (26814) : solution metal acid process leach
# | Label Y02P-3 (#23) (20671) : group rsup r compound formula
# | Label Y02P-4 (#24) (50421) : electrode battery layer cell positive
# | Label Y02P-5 (#25) (53058) : substrate solder surface layer semiconductor
# | Label Y02P-6 (#26) (37878) : heat chamber gas blade tube
# | Label Y02P-7 (#27) (34457) : metal material iron copper furnace
# | Label Y02P-8 (#28) (17568) : polymer organic display soybean biomass
# | Label Y02P-9 (#29) (23415) : layer silicon substrate powder semiconductor
# | Label Y02E-0 (#30) (31774) : battery charge cell power voltage
# | Label Y02E-1 (#31) (30654) : fuel gas hydrogen water heat
# | Label Y02E-2 (#32) (45363) : plate battery wind blade assembly
# | Label Y02E-3 (#33) (39173) : layer electrode display substrate battery
# | Label Y02E-4 (#34) (27291) : cell fuel solar layer electrode
# | Label Y02E-5 (#35) (39475) : heat fuel fluid cell flow
# | Label Y02E-6 (#36) (23652) : layer semiconductor solar silicon substrate
# | Label Y02E-7 (#37) (60713) : electrode lithium electrolyte material battery
# | Label Y02E-8 (#38) (58086) : power battery wind voltage current
# | Label Y02E-9 (#39) (10470) : wave rod transducer reflector radiation
# | Label Y02D-0 (#40) (51576) : power display device information unit
# | Label Y02D-1 (#41) (38645) : memory data bus device interface
# | Label Y02D-2 (#42) (32840) : network packet resource data node
# | Label Y02D-3 (#43) (39103) : memory cache data processor request
# | Label Y02D-4 (#44) (45436) : communication wireless station transmission radio
# | Label Y02D-5 (#45) (36399) : network wireless device resource mobile
# | Label Y02D-6 (#46) (40921) : communication wireless network terminal mobile
# | Label Y02D-7 (#47) (41280) : signal clock circuit power data
# | Label Y02D-8 (#48) (34500) : signal antenna page station ue
# | Label Y02D-9 (#49) (39710) : power device processor mode state
# | Label Y02W-0 (#50) (32636) : material polymer polyester resin polyurethane
# | Label Y02W-1 (#51) (31901) : water waste solution treatment system
# | Label Y02W-2 (#52) (36282) : container wall member end open
# | Label Y02W-3 (#53) (40235) : cement composition concrete ash cementitious
# | Label Y02W-4 (#54) (30392) : waste material compost plastic drum
# | Label Y02W-5 (#55) (38413) : container reusable bag tire plastic
# | Label Y02W-6 (#56) (42152) : waste organic rubber oil process
# | Label Y02W-7 (#57) (63061) : wastewater sludge water treatment tank
# | Label Y02W-8 (#58) (17632) : waste material product mold plant
# | Label Y02W-9 (#59) (27541) : paper pulp fiber material recycle
# | Label Y02C-0 (#60) (58086) : gas stream dioxide carbon co
# | Label Y02C-1 (#61) (22318) : catalyst compound oxide gas carbon
# | Label Y02C-2 (#62) (35474) : formation gas exhaust chamber fluid
# | Label Y02C-3 (#63) (22717) : catalyst gas exhaust nox ammonia
# | Label Y02C-4 (#64) (39774) : gas carbon dioxide co hydrogen
# | Label Y02C-5 (#65) (27693) : membrane separation gas co polyimide
# | Label Y02C-6 (#66) (46349) : co gas dioxide carbon absorbent
# | Label Y02C-7 (#67) (41631) : gas dioxide carbon stream absorbent
# | Label Y02C-8 (#68) (30768) : metal zeolite adsorbent framework organic
# | Label Y02C-9 (#69) (35428) : adsorption adsorbent gas bed swing
# | Label Y02T-0 (#70) (31701) : layer electrode material wing composite
# | Label Y02T-1 (#71) (59117) : exhaust engine fuel combustion air
# | Label Y02T-2 (#72) (33870) : portion member side wheel rotor
# | Label Y02T-3 (#73) (24095) : engine fuel air combustion intake
# | Label Y02T-4 (#74) (45688) : vehicle motor electric power battery
# | Label Y02T-5 (#75) (37479) : vehicle charge control value electric
# | Label Y02T-6 (#76) (33443) : vehicle charge battery power electric
# | Label Y02T-7 (#77) (26624) : gear drive shaft motor clutch
# | Label Y02T-8 (#78) (43147) : turbine blade airfoil edge wall
# | Label Y02T-9 (#79) (51439) : engine fuel combustion valve cylinder
# |
# /var/folders/0j/wnvgdqzd6ylfts3hrw81r15r0000gn/T/ipykernel_12371/1328415068.py:9: RuntimeWarning: The training result may differ even with fixed seed if `workers` != 1.
#   PLDA_model_IDF.train(10)
# Start training model:
# <Basic Info>
# /var/folders/0j/wnvgdqzd6ylfts3hrw81r15r0000gn/T/ipykernel_12371/1328415068.py:25: RuntimeWarning: The training result may differ even with fixed seed if `workers` != 1.
#   PLDA_model_ONE.train(10)
# | PLDAModel (current version: 0.12.5)
# | 40617 docs, 2967403 words
# | Total Vocabs: 36754, Used Vocabs: 36754
# | Entropy of words: 7.47317
# | Entropy of term-weighted words: 7.47317
# | Removed Vocabs: <NA>
# | Label of docs and its distribution
# |  Y02A: 5120
# |  Y02B: 5157
# |  Y02P: 5156
# |  Y02E: 5147
# |  Y02D: 5195
# |  Y02W: 5073
# |  Y02C: 5172
# |  Y02T: 5159
# |
# <Training Info>
# | Iterations: 100, Burn-in steps: 5
# | Optimization Interval: 10
# | Log-likelihood per word: -7.13216
# |
# <Initial Parameters>
# | tw: TermWeight.ONE
# | min_cf: 0 (minimum collection frequency of words)
# | min_df: 0 (minimum document frequency of words)
# | rm_top: 0 (the number of top words to be removed)
# | latent_topics: 0 (the number of latent topics, which are shared to all documents, between 1 ~ 32767)
# | topics_per_label: 10 (the number of topics per label between 1 ~ 32767)
# | alpha: [0.1] (hyperparameter of Dirichlet distribution for document-topic, given as a single `float` in case of symmetric prior and as a list with length `k` of `float` in case of asymmetric prior.)
# | eta: 0.01 (hyperparameter of Dirichlet distribution for topic-word)
# | seed: 42 (random seed)
# | trained in version 0.12.5
# |
# <Parameters>
# | alpha (Dirichlet prior on the per-document topic distributions)
# |  [0.00655309 0.00469219 0.00430133 0.00642706 0.00542447 0.00559358
# |   0.00561327 0.00672374 0.00539863 0.00548842 0.00333133 0.00927123
# |   0.00640848 0.00472065 0.00601994 0.00534937 0.00649487 0.0054328
# |   0.00415594 0.00600135 0.00550644 0.00536476 0.00632589 0.00434545
# |   0.00543088 0.00560585 0.00597215 0.0054313  0.00661724 0.00592795
# |   0.005443   0.00545402 0.00575934 0.00632919 0.00626196 0.00351988
# |   0.00580461 0.00741766 0.00567046 0.00511514 0.00634831 0.00602329
# |   0.0064284  0.00680159 0.0064278  0.00577294 0.00559196 0.00548001
# |   0.00552762 0.00555621 0.00509385 0.00543098 0.00604462 0.00633691
# |   0.00538115 0.00735769 0.00639936 0.00636145 0.00512399 0.00526826
# |   0.0054095  0.00429625 0.00485767 0.00717906 0.0055276  0.00571853
# |   0.00622137 0.00640988 0.00648248 0.00537013 0.00568888 0.00652046
# |   0.00611447 0.00433487 0.00651017 0.00716937 0.0052505  0.00577636
# |   0.0067255  0.00658344]
# | eta (Dirichlet prior on the per-topic word distribution)
# |  0.01
# |
# <Topics>
# | Label Y02A-0 (#0) (44885) : method invention composition use cell
# | Label Y02A-1 (#1) (29886) : gas exhaust engine catalyst system
# | Label Y02A-2 (#2) (21016) : heat water system liquid temperature
# | Label Y02A-3 (#3) (33596) : method material water use process
# | Label Y02A-4 (#4) (35465) : system method data signal one
# | Label Y02A-5 (#5) (30549) : water system air include control
# | Label Y02A-6 (#6) (34618) : plant method acid protein sequence
# | Label Y02A-7 (#7) (49590) : surface wall first structure form
# | Label Y02A-8 (#8) (25836) : compound composition method invention use
# | Label Y02A-9 (#9) (21885) : sensor system water provide include
# | Label Y02B-0 (#10) (20188) : light emit lead device source
# | Label Y02B-1 (#11) (118377) : voltage power switch circuit control
# | Label Y02B-2 (#12) (42757) : solar panel surface module include
# | Label Y02B-3 (#13) (20279) : lamp light lead first discharge
# | Label Y02B-4 (#14) (31110) : control time system method operation
# | Label Y02B-5 (#15) (29713) : power system energy device load
# | Label Y02B-6 (#16) (49196) : heat air system temperature water
# | Label Y02B-7 (#17) (31452) : power control circuit current lead
# | Label Y02B-8 (#18) (22797) : water include air housing chamber
# | Label Y02B-9 (#19) (42508) : light device control system one
# | Label Y02P-0 (#20) (28689) : power system control energy device
# | Label Y02P-1 (#21) (40352) : system process data control device
# | Label Y02P-2 (#22) (39155) : metal solution process contain method
# | Label Y02P-3 (#23) (25832) : group compound formula r acid
# | Label Y02P-4 (#24) (36315) : electrode battery cell include layer
# | Label Y02P-5 (#25) (41489) : first second surface include substrate
# | Label Y02P-6 (#26) (39477) : heat gas chamber apparatus flow
# | Label Y02P-7 (#27) (21755) : material method glass form fiber
# | Label Y02P-8 (#28) (46973) : catalyst process produce gas method
# | Label Y02P-9 (#29) (38914) : layer method form substrate material
# | Label Y02E-0 (#30) (47528) : power battery system control voltage
# | Label Y02E-1 (#31) (27679) : method process produce hydrogen use
# | Label Y02E-2 (#32) (42017) : battery first include second portion
# | Label Y02E-3 (#33) (45972) : layer substrate first device include
# | Label Y02E-4 (#34) (41205) : heat gas fuel system flow
# | Label Y02E-5 (#35) (20232) : power system current method device
# | Label Y02E-6 (#36) (22839) : fuel cell membrane stack assembly
# | Label Y02E-7 (#37) (59493) : electrode material battery lithium electrolyte
# | Label Y02E-8 (#38) (30786) : solar one panel support energy
# | Label Y02E-9 (#39) (28333) : wind turbine blade rotor shaft
# | Label Y02D-0 (#40) (43566) : power unit control device apparatus
# | Label Y02D-1 (#41) (41566) : memory first data second include
# | Label Y02D-2 (#42) (42710) : network data node device packet
# | Label Y02D-3 (#43) (42475) : device system sensor power one
# | Label Y02D-4 (#44) (45358) : communication wireless station system terminal
# | Label Y02D-5 (#45) (36195) : device power system method mobile
# | Label Y02D-6 (#46) (35707) : data transmission channel method communication
# | Label Y02D-7 (#47) (42896) : signal circuit power voltage clock
# | Label Y02D-8 (#48) (36639) : device method ue first communication
# | Label Y02D-9 (#49) (33203) : memory data system power device
# | Label Y02W-0 (#50) (32012) : material process method contain polymer
# | Label Y02W-1 (#51) (25633) : metal method acid solution contain
# | Label Y02W-2 (#52) (40978) : container portion wall form member
# | Label Y02W-3 (#53) (43613) : water treatment wastewater system tank
# | Label Y02W-4 (#54) (36963) : material waste apparatus plastic device
# | Label Y02W-5 (#55) (51448) : material composition cement method water
# | Label Y02W-6 (#56) (38528) : waste process method organic water
# | Label Y02W-7 (#57) (38567) : gas liquid chamber flow air
# | Label Y02W-8 (#58) (28456) : process material method fiber pulp
# | Label Y02W-9 (#59) (23923) : system water method device heat
# | Label Y02C-0 (#60) (35841) : gas co liquid heat stream
# | Label Y02C-1 (#61) (22195) : gas carbon compound contain method
# | Label Y02C-2 (#62) (19960) : formation may fluid hydrocarbon method
# | Label Y02C-3 (#63) (59017) : gas stream process adsorption pressure
# | Label Y02C-4 (#64) (31931) : membrane separation gas method material
# | Label Y02C-5 (#65) (36504) : gas exhaust system include air
# | Label Y02C-6 (#66) (50008) : gas stream dioxide carbon co
# | Label Y02C-7 (#67) (40910) : carbon dioxide gas co method
# | Label Y02C-8 (#68) (36410) : catalyst oxide metal method material
# | Label Y02C-9 (#69) (27212) : gas one flow least first
# | Label Y02T-0 (#70) (28459) : material layer electrode include method
# | Label Y02T-1 (#71) (41440) : exhaust gas fuel engine system
# | Label Y02T-2 (#72) (40108) : turbine include blade first surface
# | Label Y02T-3 (#73) (22154) : battery charge vehicle system include
# | Label Y02T-4 (#74) (50355) : power electric voltage vehicle system
# | Label Y02T-5 (#75) (53261) : control vehicle drive motor engine
# | Label Y02T-6 (#76) (19922) : heat air cool system fluid
# | Label Y02T-7 (#77) (38299) : engine combustion valve chamber air
# | Label Y02T-8 (#78) (42439) : first portion include member second
# | Label Y02T-9 (#79) (49804) : engine control fuel combustion time
# |
#
# Start training model:
# /var/folders/0j/wnvgdqzd6ylfts3hrw81r15r0000gn/T/ipykernel_12371/1328415068.py:41: RuntimeWarning: The training result may differ even with fixed seed if `workers` != 1.
#   PLDA_model_PMI.train(10)
# <Basic Info>
# | PLDAModel (current version: 0.12.5)
# | 40617 docs, 2967403 words
# | Total Vocabs: 36754, Used Vocabs: 36754
# | Entropy of words: 7.47317
# | Entropy of term-weighted words: 8.31698
# | Removed Vocabs: <NA>
# | Label of docs and its distribution
# |  Y02A: 5120
# |  Y02B: 5157
# |  Y02P: 5156
# |  Y02E: 5147
# |  Y02D: 5195
# |  Y02W: 5073
# |  Y02C: 5172
# |  Y02T: 5159
# |
# <Training Info>
# | Iterations: 100, Burn-in steps: 5
# | Optimization Interval: 10
# | Log-likelihood per word: -7.43285
# |
# <Initial Parameters>
# | tw: TermWeight.PMI
# | min_cf: 0 (minimum collection frequency of words)
# | min_df: 0 (minimum document frequency of words)
# | rm_top: 0 (the number of top words to be removed)
# | latent_topics: 0 (the number of latent topics, which are shared to all documents, between 1 ~ 32767)
# | topics_per_label: 10 (the number of topics per label between 1 ~ 32767)
# | alpha: [0.1] (hyperparameter of Dirichlet distribution for document-topic, given as a single `float` in case of symmetric prior and as a list with length `k` of `float` in case of asymmetric prior.)
# | eta: 0.01 (hyperparameter of Dirichlet distribution for topic-word)
# | seed: 42 (random seed)
# | trained in version 0.12.5
# |
# <Parameters>
# | alpha (Dirichlet prior on the per-document topic distributions)
# |  [0.00420427 0.00531601 0.0041557  0.0061167  0.0044389  0.00577045
# |   0.00375522 0.00501086 0.00351076 0.00385295 0.00443103 0.00641249
# |   0.00507454 0.00493119 0.00540648 0.00350956 0.00438379 0.00490351
# |   0.00448289 0.00490814 0.00452145 0.00548753 0.00497275 0.00431214
# |   0.00537108 0.00537298 0.00476217 0.00542083 0.00399063 0.00364201
# |   0.00512468 0.0038963  0.00559439 0.00500288 0.00483379 0.00445604
# |   0.00520688 0.0057308  0.00539685 0.00533335 0.00541204 0.00481996
# |   0.00526299 0.00488284 0.00548194 0.00518596 0.00436439 0.00537245
# |   0.00440409 0.00480145 0.00538032 0.00428862 0.00470445 0.00538277
# |   0.00564762 0.00502152 0.00539081 0.00578519 0.00436227 0.00478537
# |   0.00562692 0.0058601  0.00471376 0.00541562 0.00371334 0.00428079
# |   0.00515159 0.00531096 0.00498468 0.0038598  0.00500251 0.00623417
# |   0.00477671 0.00404176 0.00561253 0.00396922 0.00581791 0.00459105
# |   0.00543712 0.00539615]
# | eta (Dirichlet prior on the per-topic word distribution)
# |  0.01
# |
# <Topics>
# | Label Y02A-0 (#0) (33257) : antibody disease composition virus vaccine
# | Label Y02A-1 (#1) (42543) : exhaust gas catalyst nox nitrogen
# | Label Y02A-2 (#2) (27665) : composition compound invention disease pharmaceutical
# | Label Y02A-3 (#3) (46319) : water air system fluid exhaust
# | Label Y02A-4 (#4) (16429) : acid plant polypeptide invention composition
# | Label Y02A-5 (#5) (45014) : water air heat filter tank
# | Label Y02A-6 (#6) (28467) : plant protein gene sequence nucleic
# | Label Y02A-7 (#7) (30834) : surface member layer panel structure
# | Label Y02A-8 (#8) (22417) : oil water r composition salt
# | Label Y02A-9 (#9) (33361) : sensor data radar analyte sample
# | Label Y02B-0 (#10) (21212) : light emit lead phosphor color
# | Label Y02B-1 (#11) (103025) : voltage switch circuit power converter
# | Label Y02B-2 (#12) (38637) : circuit voltage current switch power
# | Label Y02B-3 (#13) (40904) : solar panel lamp roof module
# | Label Y02B-4 (#14) (49179) : power device energy load control
# | Label Y02B-5 (#15) (28212) : lamp power control light lead
# | Label Y02B-6 (#16) (46547) : heat air exchanger water temperature
# | Label Y02B-7 (#17) (23269) : panel heat element hvac surface
# | Label Y02B-8 (#18) (21384) : compressor refrigeration valve refrigerant water
# | Label Y02B-9 (#19) (35748) : light control sensor device source
# | Label Y02P-0 (#20) (38004) : control tool process machine device
# | Label Y02P-1 (#21) (40583) : catalyst process reaction acid hydrocarbon
# | Label Y02P-2 (#22) (26996) : data process system machine control
# | Label Y02P-3 (#23) (22948) : group compound rsup formula r
# | Label Y02P-4 (#24) (50645) : electrode battery layer cell positive
# | Label Y02P-5 (#25) (42582) : solder surface substrate semiconductor board
# | Label Y02P-6 (#26) (38243) : blade light layer substrate material
# | Label Y02P-7 (#27) (41864) : metal solution copper iron contain
# | Label Y02P-8 (#28) (29245) : plant heat gas reactor produce
# | Label Y02P-9 (#29) (27919) : layer silicon substrate powder semiconductor
# | Label Y02E-0 (#30) (39541) : battery power charge voltage control
# | Label Y02E-1 (#31) (36405) : fuel heat gas hydrogen water
# | Label Y02E-2 (#32) (47848) : plate portion assembly member battery
# | Label Y02E-3 (#33) (32304) : layer substrate film display organic
# | Label Y02E-4 (#34) (37166) : layer cell electrode semiconductor substrate
# | Label Y02E-5 (#35) (27083) : battery cell stack module energy
# | Label Y02E-6 (#36) (27596) : fuel cell coolant reactor nuclear
# | Label Y02E-7 (#37) (52509) : electrode lithium electrolyte material battery
# | Label Y02E-8 (#38) (50390) : solar power battery cell voltage
# | Label Y02E-9 (#39) (15300) : wind blade turbine rotor pitch
# | Label Y02D-0 (#40) (47656) : power unit device display processing
# | Label Y02D-1 (#41) (36967) : memory processor core device data
# | Label Y02D-2 (#42) (36914) : network packet link data node
# | Label Y02D-3 (#43) (40688) : memory data cache processor write
# | Label Y02D-4 (#44) (48870) : communication wireless network station mobile
# | Label Y02D-5 (#45) (39128) : device power network compute mobile
# | Label Y02D-6 (#46) (42892) : communication wireless transmission access channel
# | Label Y02D-7 (#47) (40614) : signal power clock circuit voltage
# | Label Y02D-8 (#48) (30543) : signal station node communication ue
# | Label Y02D-9 (#49) (36171) : device data memory power processor
# | Label Y02W-0 (#50) (38014) : material fiber polymer composition cement
# | Label Y02W-1 (#51) (30149) : water glass waste material electrode
# | Label Y02W-2 (#52) (41575) : container wall reusable bag portion
# | Label Y02W-3 (#53) (32394) : cement composition ash fly concrete
# | Label Y02W-4 (#54) (41403) : material compost water apparatus filter
# | Label Y02W-5 (#55) (26240) : material layer tire plastic foam
# | Label Y02W-6 (#56) (36730) : acid rubber oil material organic
# | Label Y02W-7 (#57) (58409) : water wastewater treatment sludge tank
# | Label Y02W-8 (#58) (25943) : waste sludge pulp treatment liquid
# | Label Y02W-9 (#59) (29798) : waste product carpet recycle material
# | Label Y02C-0 (#60) (58818) : gas stream co dioxide carbon
# | Label Y02C-1 (#61) (24423) : oxide catalyst metal membrane group
# | Label Y02C-2 (#62) (28492) : formation exhaust nox may catalyst
# | Label Y02C-3 (#63) (51236) : gas stream carbon hydrogen dioxide
# | Label Y02C-4 (#64) (29949) : gas membrane co carbon solution
# | Label Y02C-5 (#65) (28619) : membrane gas separation polyimide flow
# | Label Y02C-6 (#66) (36389) : gas co exhaust dioxide air
# | Label Y02C-7 (#67) (41445) : dioxide carbon gas co flue
# | Label Y02C-8 (#68) (32021) : metal zeolite adsorbent framework material
# | Label Y02C-9 (#69) (29126) : adsorbent adsorption bed gas process
# | Label Y02T-0 (#70) (25386) : wing aircraft layer surface composite
# | Label Y02T-1 (#71) (67493) : exhaust engine combustion air fuel
# | Label Y02T-2 (#72) (24857) : vehicle assembly battery wheel charge
# | Label Y02T-3 (#73) (29503) : fuel engine value sensor control
# | Label Y02T-4 (#74) (59185) : vehicle power electric charge motor
# | Label Y02T-5 (#75) (21027) : vehicle charge battery system electric
# | Label Y02T-6 (#76) (23229) : electrode battery cell material lithium
# | Label Y02T-7 (#77) (30691) : drive motor gear shaft torque
# | Label Y02T-8 (#78) (49272) : turbine blade portion side airfoil
# | Label Y02T-9 (#79) (55550) : engine fuel combustion control valve
# |
